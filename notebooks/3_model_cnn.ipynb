# %% [markdown]
# # 3 — CNN Model (VGG-style)
#
# Train and evaluate a VGG-style CNN (`BaselineModel`) on the pre-processed spectrograms. The model treats each spectrogram as a 4-channel image (one per brain region) and classifies it into 6 activity classes using KL divergence loss against expert vote distributions.
#
# **Architecture:** two convolutional blocks (32→64, 128→256 channels), adaptive average pooling, two-layer MLP head with dropout.
#
# **Training details:** AdamW (`lr=1e-3`, `weight_decay=1e-4`), cosine LR schedule, mixup augmentation (`α=0.4`), `bf16-mixed` precision, 50 epochs max with early stopping. Sanity-check trainers (`fast_dev_run`, `overfit_batches`) are included before the full run.

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

import torch

import pytorch_lightning as pl
from pytorch_lightning.callbacks import (
    EarlyStopping,
    LearningRateMonitor,
    ModelCheckpoint,
    RichProgressBar,
)
from pytorch_lightning.loggers import TensorBoardLogger
from tensorboard.backend.event_processing.event_accumulator import EventAccumulator

from src.dataset import *
from src.lightning import *
from src.models import *
from src.params import *
from src.utils import *

# %% [markdown]
# # Callbacks, logger et trainers

# %%
callbacks = [
    ModelCheckpoint(
        dirpath="checkpoints/v2",
        monitor="val_loss",
        mode="min",
        save_top_k=1,
        save_last=True,
        filename="{epoch:02d}-{val_loss:.3f}",
    ),
    EarlyStopping(
        monitor="val_loss",
        patience=12,
        mode="min",
        min_delta=1e-2,
    ),
    LearningRateMonitor(logging_interval="epoch"),
    RichProgressBar(),
]

logger = TensorBoardLogger(save_dir="logs/", name="v2", version=None)

# %%
trainer_full = pl.Trainer(
    max_epochs=50,
    accelerator="auto",
    devices="auto",
    precision="bf16-mixed",
    callbacks=callbacks,
    logger=logger,
    enable_progress_bar=True,
    log_every_n_steps=10,
)
# Out:
# Using bfloat16 Automatic Mixed Precision (AMP)
# GPU available: True (mps), used: True
# TPU available: False, using: 0 TPU cores
# 💡 Tip: For seamless cloud logging and experiment tracking, try installing [litlogger](https://pypi.org/project/litlogger/) to enable LitLogger, which logs metrics and artifacts automatically to the Lightning Experiments platform.

# %% [markdown]
# ## Sanity check trainers

# %%
trainer_test = pl.Trainer(fast_dev_run=True, accelerator="auto", devices="auto")

trainer_overfit = pl.Trainer(
    overfit_batches=10,
    accelerator="auto",
    devices="auto",
    max_epochs=50,
    log_every_n_steps=1,
)

# %% [markdown]
# ## Instantiation

# %%
files_dir = PROCESSED_DIR / "cropped" / "files"
metadata = pd.read_csv(DATA_DIR / "train.csv")
dm = BrainDataModule(metadata=metadata, spec_dir= files_dir, batch_size= 32, num_workers= 8)
model = BaselineModel(n_channels=4, n_classes=6)
lit_model = BrainLightning(model, lr= 1e-3, mixup= True)

# %% [markdown]
# ## Train

# %%
trainer_full.fit(lit_model, dm)
# Out:
# [setup] Loading splits from cache: /Users/pablorougerie/code/Projets/brain_waves/data/cache/5_at_seed_273.json
# [setup] Cache loaded — 5 folds found
# [Check] Train set distribution:
#  expert_consensus
# GPD        0.105983
# GRDA       0.107885
# LPD        0.151331
# LRDA       0.054930
# Other      0.425541
# Seizure    0.154330
# [Check] Val distribution:
#  expert_consensus
# GPD        0.106234
# GRDA       0.107989
# LPD        0.151302
# LRDA       0.054726
# Other      0.425519
# Seizure    0.154229
# [Check] Train: 13672 samples, 1558 patients
# [Check] Val:   3417 samples, 392 patients
# [Check] Top 5 patients train:
# patient_id
# 30631    270
# 28330    250
# 38549    205
# 35225    189
# 56450    182
# [Check] Top 5 patients val:
# patient_id
# 17408    177
# 35627    171
# 1218     122
# 18815     92
# 55148     92
# ...

# %% [markdown]
# ## Analyse

# %%
def plot_losses(log_dir="logs/v2"):
    versions = sorted(
        Path(log_dir).glob("version_*"),
        key=lambda p: int(p.name.split("_")[-1])
    )
    ea = EventAccumulator(str(versions[-1]))
    ea.Reload()

    def to_df(tag):
        events = ea.Scalars(tag)
        # e.step is global step (batches), not epoch — use index instead
        return pd.DataFrame({"epoch": range(len(events)), tag: [e.value for e in events]})

    train = to_df("train_loss")
    val   = to_df("val_loss")

    fig, ax = plt.subplots(figsize=(8, 4))
    ax.plot(train["epoch"], train["train_loss"], label="train loss")
    ax.plot(val["epoch"],   val["val_loss"],     label="val loss")
    ax.set_xlabel("Epoch")
    ax.set_ylabel("KL Loss")
    ax.legend()
    ax.grid(True, alpha=0.3)
    plt.tight_layout()
    plt.show()

# %%
plot_losses()

# %%
best_score = callbacks[0].best_model_score
print(f"Best val_loss: {best_score:.4f}")
# Out:
# Best val_loss: 0.7090

# %% [markdown]
# ## Conclusion
#
# The VGG-style CNN (`BaselineModel`, ~406K parameters) trained with mixup and AdamW achieves:
# **Best val_loss: 0.7090** (KL divergence) — well below the dummy baseline of 1.38.
#
# The model converges cleanly with the cosine LR schedule. This is the reference architecture against which hybrid models will be compared.
#
# **Next:** test hybrid CNN+LSTM architectures to see if temporal modelling helps (`4_hybrid_parallel_model`).
